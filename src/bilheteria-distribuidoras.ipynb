# %%
# Carregamento de arquivos .csv
import pandas as pd
from pathlib import Path
pasta_csv = Path("../db/bilheteria/distribuidoras")
arquivos = sorted(pasta_csv.glob("*.csv"))
dataframes = []
for a in arquivos:
  df = pd.read_csv(a, sep=";", low_memory=False)
  dataframes.append(df)

df_original = pd.concat(dataframes, ignore_index=True, sort=False)

# %%
df = df_original.copy()
df = df.rename(columns={
  'DATA_EXIBICAO': 'data_exibicao',
  'TITULO_ORIGINAL': 'titulo_original',
  'TITULO_BRASIL': 'titulo_brasil',
  'CPB_ROE': 'cpb_roe',
  'PAIS_OBRA': 'pais_obra',
  'REGISTRO_SALA': 'registro_sala',
  'NOME_SALA': 'nome_sala',
  'PUBLICO': 'publico',
  'REGISTRO_GRUPO_EXIBIDOR': 'registro_grupo_exibidor',
  'REGISTRO_EXIBIDOR': 'registro_exibidor',
  'REGISTRO_COMPLEXO': 'registro_complexo',
  'MUNICIPIO_SALA_COMPLEXO': 'municipio_sala_complexo',
  'UF_SALA_COMPLEXO': 'uf_sala_complexo',
  'RAZAO_SOCIAL_DISTRIBUIDORA': 'razao_social_distribuidora',
  'CNPJ_DISTRIBUIDORA': 'cnpj_distribuidora',
  'NR_PROTOCOLO_ENVIO': 'nr_protocolo_envio',
  'DATA_HORA_ENVIO_PROTOCOLO': 'data_hora_envio_protocolo'
})

# %%
display(df.head(10))
# Out:
#   data_exibicao      titulo_original       titulo_brasil         cpb_roe  \
# 0    01/01/2014  A COLEÇÃO INVISÍVEL                 NaN  B1201666700000
# 1    01/01/2014       A TOUCH OF SIN  UM TOQUE DE PECADO  E1600132700000
# 2    01/01/2014       A TOUCH OF SIN  UM TOQUE DE PECADO  E1600132700000
# 3    01/01/2014       A TOUCH OF SIN  UM TOQUE DE PECADO  E1600132700000
# 4    01/01/2014           ABOUT TIME    QUESTÃO DE TEMPO  E1402624700000
# 5    01/01/2014           ABOUT TIME    QUESTÃO DE TEMPO  E1402624700000
# 6    01/01/2014           ABOUT TIME    QUESTÃO DE TEMPO  E1402624700000
# 7    01/01/2014           ABOUT TIME    QUESTÃO DE TEMPO  E1402624700000
# 8    01/01/2014           ABOUT TIME    QUESTÃO DE TEMPO  E1402624700000
# 9    01/01/2014           ABOUT TIME    QUESTÃO DE TEMPO  E1402624700000
#
#         pais_obra  registro_sala                            nome_sala  \
# 0          BRASIL            NaN                        CINE BRASILIA
# 1           CHINA            NaN  CINE CULTURA LIBERTY MALL (SALA 02)
# 2           CHINA            NaN      ESPACO UNIB DE CINEMA (SALA 05)
# 3           CHINA      5000866.0                ESPAÇO ITAU COUNTRY 8
# 4  ESTADOS UNIDOS      5000674.0                          ABC PLAZA 6
# 5  ESTADOS UNIDOS      5000795.0              ANÁLIA FRANCO - SALA 04
# 6  ESTADOS UNIDOS            NaN                   ARCOPLEX ALDEOTA 1
# 7  ESTADOS UNIDOS            NaN            ARCOPLEX JARAGUA DO SUL 1
# 8  ESTADOS UNIDOS            NaN        ARCOPLEX PATIO CHAPECO 1 - 3D
# 9  ESTADOS UNIDOS            NaN              ARCOPLEX VIA CATARINA 1
#
#    publico  registro_grupo_exibidor  registro_exibidor  registro_complexo  \
# 0        4                      NaN                NaN                NaN
# 1        0                      NaN                NaN                NaN
# 2       62                      NaN                NaN                NaN
# 3       16                6000029.0             1944.0             2738.0
# 4       14                6000018.0             1843.0              896.0
# 5       60                6000058.0              749.0             2622.0
# 6        0                      NaN                NaN                NaN
# 7        0                      NaN                NaN                NaN
# 8       30                      NaN                NaN                NaN
# 9        0                      NaN                NaN                NaN
#
#   municipio_sala_complexo uf_sala_complexo  \
# 0                     NaN              NaN
# 1                     NaN              NaN
# 2                     NaN              NaN
# 3            PORTO ALEGRE               RS
# 4             SANTO ANDRÉ               SP
# 5               SÃO PAULO               SP
# 6                     NaN              NaN
# 7                     NaN              NaN
# 8                     NaN              NaN
# 9                     NaN              NaN
#
#                 razao_social_distribuidora  cnpj_distribuidora  \
# 0  PROVIDENCE DISTRIBUIDORA DE FILMES LTDA  08.656.129/0001-64
# 1          SM DISTRIBUIDORA DE FILMES LTDA  08.257.054/0001-49
# 2          SM DISTRIBUIDORA DE FILMES LTDA  08.257.054/0001-49
# 3          SM DISTRIBUIDORA DE FILMES LTDA  08.257.054/0001-49
# 4   COLUMBIA TRISTAR FILMES DO BRASIL LTDA  00.979.601/0001-98
# 5   COLUMBIA TRISTAR FILMES DO BRASIL LTDA  00.979.601/0001-98
# 6   COLUMBIA TRISTAR FILMES DO BRASIL LTDA  00.979.601/0001-98
# 7   COLUMBIA TRISTAR FILMES DO BRASIL LTDA  00.979.601/0001-98
# 8   COLUMBIA TRISTAR FILMES DO BRASIL LTDA  00.979.601/0001-98
# 9   COLUMBIA TRISTAR FILMES DO BRASIL LTDA  00.979.601/0001-98
#
#    nr_protocolo_envio data_hora_envio_protocolo
# 0      21014368003314                       NaN
# 1      31011026001914                       NaN
# 2      31011026001914                       NaN
# 3      31011026001914                       NaN
# 4      31006058001814                       NaN
# 5      31006058001814                       NaN
# 6      31006058001814                       NaN
# 7      31006058001814                       NaN
# 8      31006058001814                       NaN
# 9      31006058001814                       NaN

# %%
# Remoção de coluna 'registro_sala'
df.drop(columns=['registro_sala'], inplace=True)

# %%
# Remoção de coluna 'nome_sala'
df.drop(columns=['nome_sala'], inplace=True)

# %%
# Remoção de coluna 'registro_grupo_exibidor'
df.drop(columns=['registro_grupo_exibidor'], inplace=True)

# %%
# Remoção de coluna 'registro_exibidor'
df.drop(columns=['registro_exibidor'], inplace=True)

# %%
# Remoção de coluna 'registro_complexo'
df.drop(columns=['registro_complexo'], inplace=True)

# %%
# Remoção de coluna 'municipio_sala_complexo'
df.drop(columns=['municipio_sala_complexo'], inplace=True)

# %%
# Remoção de coluna 'cnpj_distribuidora'
df.drop(columns=['cnpj_distribuidora'], inplace=True)

# %%
# Remoção de coluna 'nr_protocolo_envio'
df.drop(columns=['nr_protocolo_envio'], inplace=True)

# %%
# Remoção de coluna 'data_hora_envio_protocolo'
df.drop(columns=['data_hora_envio_protocolo'], inplace=True)

# %%
# Tratamento de coluna 'data_exibicao'
df['data_exibicao'] = pd.to_datetime(df['data_exibicao'], format='%d/%m/%Y', dayfirst=True, errors='coerce')

# %%
display(df.head())
# Out:
#   data_exibicao      titulo_original       titulo_brasil         cpb_roe  \
# 0    2014-01-01  A COLEÇÃO INVISÍVEL                 NaN  B1201666700000
# 1    2014-01-01       A TOUCH OF SIN  UM TOQUE DE PECADO  E1600132700000
# 2    2014-01-01       A TOUCH OF SIN  UM TOQUE DE PECADO  E1600132700000
# 3    2014-01-01       A TOUCH OF SIN  UM TOQUE DE PECADO  E1600132700000
# 4    2014-01-01           ABOUT TIME    QUESTÃO DE TEMPO  E1402624700000
#
#         pais_obra                            nome_sala  publico  \
# 0          BRASIL                        CINE BRASILIA        4
# 1           CHINA  CINE CULTURA LIBERTY MALL (SALA 02)        0
# 2           CHINA      ESPACO UNIB DE CINEMA (SALA 05)       62
# 3           CHINA                ESPAÇO ITAU COUNTRY 8       16
# 4  ESTADOS UNIDOS                          ABC PLAZA 6       14
#
#   municipio_sala_complexo uf_sala_complexo  \
# 0                     NaN              NaN
# 1                     NaN              NaN
# 2                     NaN              NaN
# 3            PORTO ALEGRE               RS
# 4             SANTO ANDRÉ               SP
#
#                 razao_social_distribuidora
# 0  PROVIDENCE DISTRIBUIDORA DE FILMES LTDA
# 1          SM DISTRIBUIDORA DE FILMES LTDA
# 2          SM DISTRIBUIDORA DE FILMES LTDA
# 3          SM DISTRIBUIDORA DE FILMES LTDA
# 4   COLUMBIA TRISTAR FILMES DO BRASIL LTDA

# %% [markdown]
# # Tratamento de valores nulos

# %%
# Tratamento de colunas 'titulo_original' e 'titulo_brasil'
# Pegar todos os registros que não tem 'titulo_brasil' e substituir pelo valor em 'titulo_original'
df['titulo_brasil'].fillna(df['titulo_original'], inplace=True)
# Out:
# /tmp/ipykernel_3458/3284118710.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['titulo_brasil'].fillna(df['titulo_original'], inplace=True)

# %%
# Remoção da coluna 'titulo_original'
df.drop(columns=['titulo_original'], inplace=True)

# %%
# Renomear 'titulo_brasil' para 'titulo'
df = df.rename(columns={'titulo_brasil': 'titulo'})

# %%
# Forçar remoção de espaços nos títulos
df['titulo'] = df['titulo'].str.strip()

# %%
# Forçar títulos em caixa alta
df['titulo'] = df['titulo'].str.upper()

# %%
display(df.count())
# Out:
# data_exibicao                 19275452
# titulo                        19275452
# cpb_roe                       19275240
# pais_obra                     19275452
# publico                       19275452
# uf_sala_complexo              18753704
# razao_social_distribuidora    19275452
# dtype: int64

# %%
# Remoção de valores nulos na coluna 'cpb_roe'
df.dropna(subset=['cpb_roe'], inplace=True)

# %%
# Remoção de valores nulos na coluna 'uf_sala_complexo'
df[df['uf_sala_complexo'].isna()]['pais_obra'].value_counts()
df.dropna(subset=['uf_sala_complexo'], inplace=True)
# Out:
# data_exibicao                 18753704
# titulo                        18753704
# cpb_roe                       18753513
# pais_obra                     18753704
# publico                       18753704
# uf_sala_complexo              18753704
# razao_social_distribuidora    18753704
# dtype: int64

# %%
display(df[df['pais_obra'].isna()])
# Out:
# Empty DataFrame
# Columns: [data_exibicao, titulo, cpb_roe, pais_obra, publico, municipio_sala_complexo, uf_sala_complexo, razao_social_distribuidora]
# Index: []

# %%
def preenche_pais_obra(registro: str):
  if registro.startswith('E'):
    return 'ESTRANGEIRO'
  else:
    return 'BRASIL'

df['pais_obra'].fillna(preenche_pais_obra, inplace=True)

# %%
display(df.count())
# Out:
# data_exibicao                 18753513
# titulo                        18753513
# cpb_roe                       18753513
# pais_obra                     18753513
# publico                       18753513
# uf_sala_complexo              18753513
# razao_social_distribuidora    18753513
# dtype: int64

# %%
display(df.count())
display(df.head())
display(df.info())
# Out:
# data_exibicao                 18747217
# titulo                        18747217
# cpb_roe                       18747217
# pais_obra                     18747217
# nome_sala                     18747217
# publico                       18747217
# municipio_sala_complexo       18747217
# uf_sala_complexo              18747217
# razao_social_distribuidora    18747217
# dtype: int64
#    data_exibicao              titulo         cpb_roe       pais_obra  \
# 3     2014-01-01  UM TOQUE DE PECADO  E1600132700000           CHINA
# 4     2014-01-01    QUESTÃO DE TEMPO  E1402624700000  ESTADOS UNIDOS
# 5     2014-01-01    QUESTÃO DE TEMPO  E1402624700000  ESTADOS UNIDOS
# 10    2014-01-01    QUESTÃO DE TEMPO  E1402624700000  ESTADOS UNIDOS
# 11    2014-01-01    QUESTÃO DE TEMPO  E1402624700000  ESTADOS UNIDOS
#
#                            nome_sala  publico municipio_sala_complexo  \
# 3              ESPAÇO ITAU COUNTRY 8       16            PORTO ALEGRE
# 4                        ABC PLAZA 6       14             SANTO ANDRÉ
# 5            ANÁLIA FRANCO - SALA 04       60               SÃO PAULO
# 10  ARCOPLEXCINEMAS- PARK EUROPEU IV        0                BLUMENAU
# 11      ARCOPLEXCINEMAS- RIO CLARO I        0               RIO CLARO
#
#    uf_sala_complexo              razao_social_distribuidora
# 3                RS         SM DISTRIBUIDORA DE FILMES LTDA
# 4                SP  COLUMBIA TRISTAR FILMES DO BRASIL LTDA
# 5                SP  COLUMBIA TRISTAR FILMES DO BRASIL LTDA
# 10               SC  COLUMBIA TRISTAR FILMES DO BRASIL LTDA
# 11               SP  COLUMBIA TRISTAR FILMES DO BRASIL LTDA
# <class 'pandas.core.frame.DataFrame'>
# Index: 18747217 entries, 3 to 19275451
# Data columns (total 9 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   data_exibicao               datetime64[ns]
#  1   titulo                      object
#  2   cpb_roe                     object
#  3   pais_obra                   object
#  4   nome_sala                   object
#  5   publico                     int64
#  6   municipio_sala_complexo     object
#  7   uf_sala_complexo            object
#  8   razao_social_distribuidora  object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 1.4+ GB
# None

# %%
# Exportando DataFrame para .csv tratado
# df.to_csv("../db/clean/bilheteria-distribuidoras.csv", index=False)
