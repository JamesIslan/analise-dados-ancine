# %%
# Carregamento de arquivos .csv
import pandas as pd
from pathlib import Path
pasta_csv = Path("../db/bilheteria/exibidoras")
arquivos = sorted(pasta_csv.glob("*.csv"))
dataframes = []
for a in arquivos:
  df = pd.read_csv(a, sep=";", low_memory=False)
  dataframes.append(df)

df_original = pd.concat(dataframes, ignore_index=True, sort=False)

# %%
df = df_original.copy()
df = df.rename(columns={
  'DATA_EXIBICAO': 'data_exibicao',
  'SESSAO': 'sessao',
  'TITULO_ORIGINAL': 'titulo_original',
  'TITULO_BRASIL': 'titulo_brasil',
  'CPB_ROE': 'cpb_roe',
  'AUDIO': 'audio',
  'LEGENDADA' : 'legendada',
  'PAIS_OBRA': 'pais_obra',
  'REGISTRO_SALA': 'registro_sala',
  'NOME_SALA': 'nome_sala',
  'PUBLICO': 'publico',
  'REGISTRO_GRUPO_EXIBIDOR': 'registro_grupo_exibidor',
  'REGISTRO_EXIBIDOR': 'registro_exibidor',
  'REGISTRO_COMPLEXO': 'registro_complexo',
  'MUNICIPIO_SALA_COMPLEXO': 'municipio_sala_complexo',
  'UF_SALA_COMPLEXO': 'uf_sala_complexo',
  'RAZAO_SOCIAL_EXIBIDORA': 'razao_social_exibidora',
  'CNPJ_EXIBIDORA': 'cnpj_exibidora',
})

# %%
# Remoção de coluna 'registro_sala'
df.drop(columns=['registro_sala'], inplace=True)

# %%
# Remoção de coluna 'registro_grupo_exibidor'
df.drop(columns=['registro_grupo_exibidor'], inplace=True)

# %%
# Remoção de coluna 'registro_exibidor'
df.drop(columns=['registro_exibidor'], inplace=True)

# %%
# Remoção de coluna 'registro_complexo'
df.drop(columns=['registro_complexo'], inplace=True)

# %%
# Remoção de coluna 'cnpj_exibidora'
df.drop(columns=['cnpj_exibidora'], inplace=True)

# %%
# Remoção de coluna 'audio'
df.drop(columns=['audio'], inplace=True)

# %%
# Remoção de coluna 'legendada'
df.drop(columns=['legendada'], inplace=True)

# %%
# Tratamento de colunas 'titulo_original' e 'titulo_brasil'
# Pegar todos os registros que não tem 'titulo_brasil' e substituir pelo valor em 'titulo_original'
df['titulo_brasil'].fillna(df['titulo_original'], inplace=True)
# Out:
# /tmp/ipykernel_3636/3284118710.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['titulo_brasil'].fillna(df['titulo_original'], inplace=True)

# %%
# Remoção da coluna 'titulo_original'
df.drop(columns=['titulo_original'], inplace=True)

# %%
# Remoção da coluna 'data_exibicao'
df.drop(columns=['data_exibicao'], inplace=True)

# %%
# Renomear 'titulo_brasil' para 'titulo'
df = df.rename(columns={'titulo_brasil': 'titulo'})

# %%
# Forçar remoção de espaços nos títulos
df['titulo'] = df['titulo'].str.strip()

# %%
# Forçar títulos em caixa alta
df['titulo'] = df['titulo'].str.upper()

# %%
# Tratamento de coluna 'sessao'
df['sessao'] = pd.to_datetime(df['sessao'], format='%d/%m/%Y %H:%M:%S', dayfirst=True, errors='coerce')

# %%
# Dropamos os registros com valores nulos
df.dropna(inplace=True)

# %%
display(df.count())
display(df.head())
display(df.info())
# Out:
# sessao                     33332815
# titulo                     33332815
# cpb_roe                    33332815
# pais_obra                  33332815
# nome_sala                  33332815
# publico                    33332815
# municipio_sala_complexo    33332815
# uf_sala_complexo           33332815
# razao_social_exibidora     33332815
# dtype: int64
#                sessao      titulo         cpb_roe       pais_obra  \
# 0 2014-06-01 14:00:00         NOÉ  E1402510400000  ESTADOS UNIDOS
# 1 2014-06-01 17:00:00         NOÉ  E1402510400000  ESTADOS UNIDOS
# 2 2014-06-01 19:00:00         NOÉ  E1402510400000  ESTADOS UNIDOS
# 3 2014-06-01 22:00:00         NOÉ  E1402510400000  ESTADOS UNIDOS
# 4 2014-06-11 13:00:00  DIVERGENTE  E1402640000000  ESTADOS UNIDOS
#
#           nome_sala  publico municipio_sala_complexo uf_sala_complexo  \
# 0  ARAPIRACA BRA 01        0               ARAPIRACA               AL
# 1  ARAPIRACA BRA 01        0               ARAPIRACA               AL
# 2  ARAPIRACA BRA 01        0               ARAPIRACA               AL
# 3  ARAPIRACA BRA 01        0               ARAPIRACA               AL
# 4  ARAPIRACA BRA 02        0               ARAPIRACA               AL
#
#               razao_social_exibidora
# 0  REDECINE BRA CINEMATOGRÁFICA S.A.
# 1  REDECINE BRA CINEMATOGRÁFICA S.A.
# 2  REDECINE BRA CINEMATOGRÁFICA S.A.
# 3  REDECINE BRA CINEMATOGRÁFICA S.A.
# 4  REDECINE BRA CINEMATOGRÁFICA S.A.
# <class 'pandas.core.frame.DataFrame'>
# Index: 33332815 entries, 0 to 33511859
# Data columns (total 9 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   sessao                   datetime64[ns]
#  1   titulo                   object
#  2   cpb_roe                  object
#  3   pais_obra                object
#  4   nome_sala                object
#  5   publico                  int64
#  6   municipio_sala_complexo  object
#  7   uf_sala_complexo         object
#  8   razao_social_exibidora   object
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 2.5+ GB
# None

# %%
# Exportando DataFrame para .csv tratado
# df.to_csv("../db/clean/bilheteria-exibidoras.csv", index=False)
