# %% [markdown]
# # Importação do arquivo .csv

# %%
import pandas as pd

def converte_int(dado: str):
  try:
    return int(dado)
  except ValueError:
    return None

df = pd.read_csv("../../db/salas-de-exibicao.csv", sep=";")

# Renomeia colunas para padrão snake_case
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#                          nome_sala  registro_sala           cnpj_sala  \
# 0          CINE COMPANY JAGUARIUNA      5003332.0  10.615.866/0001-60
# 1  CINE COMPANY JAGUARIUNA SALA 01      5003331.0  10.615.866/0001-60
# 2                 PARK SHOPPING 01      5003401.0  00.779.721/0054-53
# 3                 PARK SHOPPING 02      5003402.0  00.779.721/0054-53
# 4                 PARK SHOPPING 03      5003403.0  00.779.721/0054-53
#
#       situacao_sala data_situacao_sala data_inicio_funcionamento_sala  \
# 0           FECHADO         29/08/2011                     16/12/2008
# 1           FECHADO         29/08/2011                     16/12/2008
# 2  EM FUNCIONAMENTO         24/04/2021                     18/11/2011
# 3  EM FUNCIONAMENTO         24/04/2021                     18/11/2011
# 4  EM FUNCIONAMENTO         24/04/2021                     18/11/2011
#
#    assentos_sala  assentos_cadeirantes  assentos_mobilidade_reduzida  \
# 0          162.0                   NaN                           NaN
# 1          162.0                   NaN                           NaN
# 2          402.0                   8.0                           5.0
# 3          370.0                   8.0                           4.0
# 4          245.0                   5.0                           3.0
#
#    assentos_obesidade  ...  municipio_complexo cep_complexo uf_complexo  \
# 0                 NaN  ...          JAGUARIÚNA    13820-000          SP
# 1                 NaN  ...          JAGUARIÚNA    13820-000          SP
# 2                 5.0  ...  SÃO CAETANO DO SUL    09531-190          SP
# 3                 4.0  ...  SÃO CAETANO DO SUL    09531-190          SP
# 4                 3.0  ...  SÃO CAETANO DO SUL    09531-190          SP
#
#   complexo_itinerante  operacao_usual  \
# 0                 NÃO       COMERCIAL
# 1                 NÃO       COMERCIAL
# 2                 NÃO       COMERCIAL
# 3                 NÃO       COMERCIAL
# 4                 NÃO       COMERCIAL
#
#                                   nome_exibidor registro_exibidor  \
# 0  02 P D & ARAUJO EMPRESA CINEMATOGRAFICA LTDA             19954
# 1  02 P D & ARAUJO EMPRESA CINEMATOGRAFICA LTDA             19954
# 2                           CINEMARK BRASIL S.A              1843
# 3                           CINEMARK BRASIL S.A              1843
# 4                           CINEMARK BRASIL S.A              1843
#
#         cnpj_exibidor situacao_exibidor                   nome_grupo_exibidor
# 0  10.615.866/0001-60         IRREGULAR  NÃO PERTENCE A NENHUM GRUPO EXIBIDOR
# 1  10.615.866/0001-60         IRREGULAR  NÃO PERTENCE A NENHUM GRUPO EXIBIDOR
# 2  00.779.721/0001-41           REGULAR                              CINEMARK
# 3  00.779.721/0001-41           REGULAR                              CINEMARK
# 4  00.779.721/0001-41           REGULAR                              CINEMARK
#
# [5 rows x 32 columns]

# %%
# Removendo registros onde registro_sala é nulo
df = df.dropna(subset=['registro_sala'])

# Converter registro_sala para inteiro
df['registro_sala'] = df['registro_sala'].astype(int)

# %%
# Convertendo `assentos_sala` para inteiro
df['assentos_sala'] = df['assentos_sala'].astype(int)

# %%
df.head()
# Out:
#                          nome_sala  registro_sala           cnpj_sala  \
# 0          CINE COMPANY JAGUARIUNA        5003332  10.615.866/0001-60
# 1  CINE COMPANY JAGUARIUNA SALA 01        5003331  10.615.866/0001-60
# 2                 PARK SHOPPING 01        5003401  00.779.721/0054-53
# 3                 PARK SHOPPING 02        5003402  00.779.721/0054-53
# 4                 PARK SHOPPING 03        5003403  00.779.721/0054-53
#
#       situacao_sala data_situacao_sala data_inicio_funcionamento_sala  \
# 0           FECHADO         29/08/2011                     16/12/2008
# 1           FECHADO         29/08/2011                     16/12/2008
# 2  EM FUNCIONAMENTO         24/04/2021                     18/11/2011
# 3  EM FUNCIONAMENTO         24/04/2021                     18/11/2011
# 4  EM FUNCIONAMENTO         24/04/2021                     18/11/2011
#
#    assentos_sala  assentos_cadeirantes  assentos_mobilidade_reduzida  \
# 0            162                   NaN                           NaN
# 1            162                   NaN                           NaN
# 2            402                   8.0                           5.0
# 3            370                   8.0                           4.0
# 4            245                   5.0                           3.0
#
#    assentos_obesidade  ...  municipio_complexo cep_complexo uf_complexo  \
# 0                 NaN  ...          JAGUARIÚNA    13820-000          SP
# 1                 NaN  ...          JAGUARIÚNA    13820-000          SP
# 2                 5.0  ...  SÃO CAETANO DO SUL    09531-190          SP
# 3                 4.0  ...  SÃO CAETANO DO SUL    09531-190          SP
# 4                 3.0  ...  SÃO CAETANO DO SUL    09531-190          SP
#
#   complexo_itinerante  operacao_usual  \
# 0                 NÃO       COMERCIAL
# 1                 NÃO       COMERCIAL
# 2                 NÃO       COMERCIAL
# 3                 NÃO       COMERCIAL
# 4                 NÃO       COMERCIAL
#
#                                   nome_exibidor registro_exibidor  \
# 0  02 P D & ARAUJO EMPRESA CINEMATOGRAFICA LTDA             19954
# 1  02 P D & ARAUJO EMPRESA CINEMATOGRAFICA LTDA             19954
# 2                           CINEMARK BRASIL S.A              1843
# 3                           CINEMARK BRASIL S.A              1843
# 4                           CINEMARK BRASIL S.A              1843
#
#         cnpj_exibidor situacao_exibidor                   nome_grupo_exibidor
# 0  10.615.866/0001-60         IRREGULAR  NÃO PERTENCE A NENHUM GRUPO EXIBIDOR
# 1  10.615.866/0001-60         IRREGULAR  NÃO PERTENCE A NENHUM GRUPO EXIBIDOR
# 2  00.779.721/0001-41           REGULAR                              CINEMARK
# 3  00.779.721/0001-41           REGULAR                              CINEMARK
# 4  00.779.721/0001-41           REGULAR                              CINEMARK
#
# [5 rows x 32 columns]

# %%
# Exportando DataFrame para .csv tratado
df.to_csv("../../db/clean/salas-de-exibicao.csv", index=False)
