# %% [markdown]
# # Carregamento dos arquivos .csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
pasta_csv = Path("../../db/obras-nao-publicitarias")
arquivos = sorted(pasta_csv.glob("*.csv"))
dataframes = []
for a in arquivos:
  df = pd.read_csv(a, sep=";", low_memory=False)
  dataframes.append(df)

df_original = pd.concat(dataframes, ignore_index=True, sort=False)

# %% [markdown]
# # Renomeação de colunas

# %%
df = df_original.copy()
df = df.rename(columns={
  'TITULO_ORIGINAL': 'titulo_original',
  'CPB': 'cpb',
  'DATA_EMISSAO_CPB': 'data_emissao_cpb',
  'SITUACAO_OBRA': 'situacao_obra',
  'TIPO_OBRA': 'tipo_obra',
  'SUBTIPO_OBRA': 'subtipo_obra',
  'CLASSIFICACAO_OBRA': 'classificacao_obra',
  'ORGANIZACAO_TEMPORAL': 'organizacao_temporal',
  'DURACAO_TOTAL_MINUTOS': 'duracao_total_minutos',
  'QUANTIDADE_EPISODIOS': 'quantidade_episodios',
  'ANO_PRODUCAO_INICIAL': 'ano_producao_inicial',
  'ANO_PRODUCAO_FINAL': 'ano_producao_final',
  'SEGMENTO_DESTINACAO_INICIAL': 'segmento_destinacao_inicial',
  'COPRODUCAO_INTERNACIONAL': 'coproducao_internacional',
  'REQUERENTE': 'requerente',
  'CNPJ_REQUERENTE': 'cnpj_requerente',
  'UF_REQUERENTE': 'uf_requerente',
  'MUNICIPIO_REQUERENTE': 'municipio_requerente'
})

# %%
df.head(10)
# Out:
#                        titulo_original             cpb data_emissao_cpb  \
# 0       " DO JEITO QUE EU FALO" - 2009  B0901092600000       29/09/2009
# 1          "EVOLUÇÃO, A FESTA DA VIDA"  B0901116200000       18/11/2009
# 2                   "MINAS PORTUGUESA"  B0901065200000       10/08/2009
# 3                               "SOLO"  B0901120600000       01/12/2009
# 4                              "TANGO"  B0901074000000       21/08/2009
# 5                                  (F)  B0901007900000       16/04/2009
# 6                       1,2,3! ÊXTASE!  B0900987500000       18/02/2009
# 7          10 ADVERTÊNCIAS E 01 BENÇÃO  B0901017100000       08/05/2009
# 8  100 ANOS DE FREVO DO SERTÃO AO CAIS  B0900994700000       06/03/2009
# 9  100 ANOS DE IMIGRAÇÃO JUDAICA NO RS  B0901008400000       20/04/2009
#
#   situacao_obra         tipo_obra   subtipo_obra  \
# 0      DEFERIDO  NÃO CLASSIFICADA  NÃO INFORMADO
# 1      DEFERIDO  NÃO CLASSIFICADA  NÃO INFORMADO
# 2      DEFERIDO  NÃO CLASSIFICADA  NÃO INFORMADO
# 3      DEFERIDO            FICÇÃO  NÃO INFORMADO
# 4      DEFERIDO  NÃO CLASSIFICADA  NÃO INFORMADO
# 5      DEFERIDO            FICÇÃO  NÃO INFORMADO
# 6      DEFERIDO  NÃO CLASSIFICADA  NÃO INFORMADO
# 7      DEFERIDO  NÃO CLASSIFICADA  NÃO INFORMADO
# 8      DEFERIDO  NÃO CLASSIFICADA  NÃO INFORMADO
# 9      DEFERIDO  NÃO CLASSIFICADA  NÃO INFORMADO
#
#                                   classificacao_obra organizacao_temporal  \
# 0                                      NÃO INFORMADO              SERIADA
# 1                                      NÃO INFORMADO              SERIADA
# 2                                      NÃO INFORMADO          NÃO SERIADA
# 3  BRASILEIRA INDEPENDENTE CONSTITUINTE DE ESPAÇO...          NÃO SERIADA
# 4                                      NÃO INFORMADO          NÃO SERIADA
# 5      BRASILEIRA CONSTITUINTE DE ESPAÇO QUALIFICADO          NÃO SERIADA
# 6                                      NÃO INFORMADO          NÃO SERIADA
# 7                                      NÃO INFORMADO          NÃO SERIADA
# 8                                      NÃO INFORMADO          NÃO SERIADA
# 9                                      NÃO INFORMADO          NÃO SERIADA
#
#   duracao_total_minutos  quantidade_episodios  ano_producao_inicial  \
# 0                   2,5                  40.0                2009.0
# 1                   312                   6.0                2009.0
# 2                    21                   NaN                2006.0
# 3                    72                   NaN                2009.0
# 4                  35,7                   NaN                2009.0
# 5                  16,5                   NaN                2008.0
# 6                     5                   NaN                2009.0
# 7                   7,5                   NaN                2005.0
# 8                  17,7                   NaN                2007.0
# 9                  43,4                   NaN                2004.0
#
#    ano_producao_final segmento_destinacao_inicial coproducao_internacional  \
# 0              2009.0                  INDEFINIDO                      NÃO
# 1              2009.0                  INDEFINIDO                      NÃO
# 2                 NaN                  INDEFINIDO                      NÃO
# 3                 NaN                  INDEFINIDO                      NÃO
# 4                 NaN                  INDEFINIDO                      NÃO
# 5                 NaN                  INDEFINIDO                      NÃO
# 6                 NaN                  INDEFINIDO                      NÃO
# 7                 NaN                  INDEFINIDO                      NÃO
# 8                 NaN                  INDEFINIDO                      NÃO
# 9                 NaN                  INDEFINIDO                      NÃO
#
#                                          requerente     cnpj_requerente  \
# 0                          FUNDAÇÃO ROBERTO MARINHO  29.527.413/0001-00
# 1                     VÍDEO CIÊNCIA PRODUÇÕES LTDA.  31.247.679/0001-41
# 2                               BEMVINDAFILMES LTDA  08.835.874/0001-70
# 3                       SP FILMES DE SÃO PAULO LTDA  59.190.843/0001-40
# 4  INTERNACIONAL - PRODUÇÕES DE CINEMA E VÍDEO LTDA  04.964.663/0001-87
# 5                           FELIPE DALL ANESE CANGA       PESSOA FÍSICA
# 6                               CORTEX DIGITAL LTDA  04.104.225/0001-49
# 7             KM70 CULTURA, ARTE E COMUNICAÇÃO LTDA  06.307.256/0001-22
# 8                             ATELIE PRODUCOES LTDA  04.149.422/0001-84
# 9                    TURNING POINT PRODUCOES EIRELI  00.325.903/0001-42
#
#   uf_requerente municipio_requerente
# 0            RJ       RIO DE JANEIRO
# 1            RJ       RIO DE JANEIRO
# 2            MG       BELO HORIZONTE
# 3            SP            SÃO PAULO
# 4            RJ       RIO DE JANEIRO
# 5            SP   SÃO CAETANO DO SUL
# 6            RJ       RIO DE JANEIRO
# 7            SP            SÃO PAULO
# 8            PE               RECIFE
# 9            RS         PORTO ALEGRE

# %% [markdown]
# # Remoção de colunas desnecessárias

# %% [markdown]
# ## Remoção da coluna `data_emissao_cpb`

# %%
df.drop(columns=['data_emissao_cpb'], inplace=True)

# %% [markdown]
# ## Remoção da coluna `situacao_obra`

# %%
df.drop(columns=['situacao_obra'], inplace=True)

# %% [markdown]
# ## Remoção da coluna `subtipo_obra`

# %%
df.drop(columns=['subtipo_obra'], inplace=True)

# %% [markdown]
# ## Remoção da coluna `quantidade_episodios`

# %%
df.drop(columns=['quantidade_episodios'], inplace=True)

# %% [markdown]
# ## Remoção da coluna `ano_producao_final`

# %%
df.drop(columns=['ano_producao_final'], inplace=True)

# %% [markdown]
# ## Remoção da coluna `coproducao_internacional`

# %%
df.drop(columns=['coproducao_internacional'], inplace=True)

# %% [markdown]
# ## Remoção da coluna `cnpj_requerente`

# %%
df.drop(columns=['cnpj_requerente'], inplace=True)

# %% [markdown]
# # Tratamento de dados

# %% [markdown]
# ## Tratamento da coluna `classificacao_obra`
#
# - Comum: Jornalístico, eventos esportivos, programa de auditório ancorado por apresentador ou religioso
# - Brasileira constituinte...: Possui vínculo com agentes econômicos ligados a grandes grupos de telecomunicação
# - Brasileira independente...: Não possui vínculo com agentes econômicos ligados a grandes grupos de telecomunicação
# Portanto, remover registros cujo tipo são "Comum"

# %%
df = df[df['classificacao_obra'] != 'COMUM']

# %% [markdown]
# ## Tratamento da coluna `uf_requerente`

# %%
df.dropna(subset=['uf_requerente'], inplace=True)

# %% [markdown]
# ## Tratamento da coluna `organizacao_temporal`

# %%
df = df[df['organizacao_temporal'] == 'NÃO SERIADA']

# %% [markdown]
# Agora que temos apenas os registros de obras não seriadas, podemos remover a coluna `organizacao_temporal`

# %%
df.drop(columns=['organizacao_temporal'], inplace=True)

# %% [markdown]
# ## Tratamento da coluna `tipo_obra`

# %%
df = df[df['tipo_obra'] != 'REALITY-SHOW']

# %% [markdown]
# ## Tratamento da coluna `duracao_total_minutos`

# %%
df['duracao_total_minutos'] = df['duracao_total_minutos'].str.replace(',', '.')
df['duracao_total_minutos'] = df['duracao_total_minutos'].astype(float)

# %%
df['duracao_total_minutos'].head(10)
# Out:
# 2     21.0
# 3     72.0
# 4     35.7
# 5     16.5
# 6      5.0
# 7      7.5
# 8     17.7
# 9     43.4
# 11    80.0
# 12    85.0
# Name: duracao_total_minutos, dtype: float64

# %% [markdown]
# ## Adição de coluna `cat_duracao`

# %%
df['cat_duracao'] = None
df.loc[df['duracao_total_minutos'] <= 15, 'cat_duracao'] = 'CURTA METRAGEM'
df.loc[(df['duracao_total_minutos'] > 15) & (df['duracao_total_minutos'] <= 70), 'cat_duracao'] = 'MÉDIA METRAGEM'
df.loc[df['duracao_total_minutos'] > 70, 'cat_duracao'] = 'LONGA METRAGEM'

# %% [markdown]
# ## Tratamento da coluna `ano_producao_inicial`

# %%
df['ano_producao_inicial'] = df['ano_producao_inicial'].astype(int)

# %%
df = df[df['ano_producao_inicial'] >= 2009]

# %% [markdown]
# ## Tratamento da coluna `segmento_destinacao_inicial`

# %%
df['segmento_destinacao_inicial'] = (
    df['segmento_destinacao_inicial']
      .str.strip()
      .replace({
          'COMUNICAÇÃO ELETRÔNICA DE MASSA POR ASSINATURA (TV PAGA)': 'TV PAGA',
          'RADIODIFUSÃO DE SONS E IMAGENS (TV ABERTA)': 'TV ABERTA',
          'OUTROS MERCADOS - AUDIOVISUAL EM CIRCUITO RESTRITO': 'CIRCUITO RESTRITO',
          'OUTROS MERCADOS - VÍDEO POR DEMANDA': 'VÍDEO POR DEMANDA',
          'OUTROS MERCADOS - AUDIOVISUAL EM TRANSPORTE COLETIVO': 'TRANSPORTE COLETIVO',
      }, regex=False)
)

# %% [markdown]
# # Tratamento de outliers

# %% [markdown]
# ## Remoção de outliers na coluna `duracao_total_minutos`
#
# ### Justificativa
# A base de dados de obras não publicitárias não faz boa distinção entre obras seriadas e não seriadas. Apesar de haver a coluna `organizacao_temporal` (cujos valores já filtramos anteriormente para obter apenas registros não seriados), esta parece não ser suficiente para agregar todas as obras seriadas. Tendo em vista que esta análise é voltada para a exibição de filmes, o tratamento de valores discrepantes de duração se faz nesessário antes de ser iniciada qualquer etapa de visualização de dados.

# %%
sns.boxplot(x='duracao_total_minutos', data=df, orient='h')
plt.title('Boxplot - Duração das produções em minutos')
plt.xlabel('Duraçao total em minutos')
plt.show()

# %% [markdown]
# ### Remoção dos registros

# %%
df = df[
  ((col := df['duracao_total_minutos']) > col.quantile(0.005)) &
  (col < col.quantile(0.995))
]

# %%
# Exportando DataFrame para .csv tratado
df.to_csv("../../db/clean/obras-nao-publicitarias.csv", index=False)
